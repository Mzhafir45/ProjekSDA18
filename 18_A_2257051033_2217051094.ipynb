# %%
class Novel:
    def _init_(self, judul, harga):
        self.judul = judul
        self.harga = harga

    def _str_(self):
        return f"Novel yang Anda beli adalah {self.judul} dengan harga {self.harga}"

list1_misteri = [
    "----Novel Genre Misteri----",
    "1. The Guardians",
    "2. The Devil All the Time",
    "3. Ivana Van Dijk"
]

list2_romance = [
    "----Novel Genre Romance----",
    "1. 1 Kos, 3 Cinta, 7 Keberuntungan",
    "2. Ancika: Dia yang Bersamaku Tahun 1995",
    "3. Dikta & Hukum"
]

list3_horror = [
    "----Novel Genre Horror----",
    "1. Surat dari Kematian",
    "2. Kisah Tanah Jawa",
    "3. Tewasnya Gagak Hitam"
]

list4_comedy = [
    "----Novel Genre Comedy----",
    "1. Ubur-Ubur Lembur",
    "2. Skripsick",
    "3. KambingJantan"
]

# Menu
def menu():
 print("Selamat datang di toko novel")
 print()
 print("1. Lihat Daftar Novel dengan genre mistery")
 print("2. Lihat Daftar Novel dengan genre romance") 
 print("3. Lihat Daftar Novel dengan genre horror")
 print("4. Lihat Daftar Novel dengan genre comedy")


print()

daftar_belanja = []
total_harga = 0

while True:
    menu()
    pilih = int(input("Pilih nomor menu: "))

    # Menampilkan daftar novel berdasarkan pilihan pengguna
    if pilih == 1:
        print("\n".join(list1_misteri))
        while True:
            misteri = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if misteri == 'selesai':
                break
            elif misteri in ['1', '2', '3']:
                if misteri == '1':
                    novel = Novel("1. The Guardians", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif misteri == '2':
                    novel = Novel("2. The Devil All the Time", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif misteri == '3':
                    novel = Novel("3. Ivana Van Dijk", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            if beli_lagi == "ya":
                menu()
                break
            elif beli_lagi == "tidak":
                break
            print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)

        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        print("Terima kasih sudah Belanja")
        break
   

    elif pilih == 2:
        print("\n".join(list2_romance))
        while True:
            romance = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if romance == 'selesai':
                break
            elif romance in ['1', '2', '3']:
                if romance == '1':
                    novel = Novel("1. 1 Kos, 3 Cinta, 7 Keberuntungan", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif romance == '2':
                    novel = Novel("2. Ancika: Dia yang Bersamaku Tahun 1995", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif romance == '3':
                    novel = Novel("3. Dikta & Hukum", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        
        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            if beli_lagi == "ya":
                menu()
                break
            elif beli_lagi == "tidak":
                break
            print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)

        print(f"Total Harga yang harus dibayar : {total_harga}")
        print()
        print("Terima kasih sudah Belanja")
        break
    elif pilih == 3:
        print("\n".join(list2_romance))
        while True:
            horor = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if horor == 'selesai':
                break
            elif horor in ['1', '2', '3']:
                if horor == '1':
                    novel = Novel("1. Surat dari Kematian", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif horor == '2':
                    novel = Novel("2. Kisah Tanah Jawa", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif horor == '3':
                    novel = Novel("3. Tewasnya Gagak Hitam", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            if beli_lagi == "ya":
                menu()
                break
            elif beli_lagi == "tidak":
                break
            print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)

        print(f"Total Harga yang harus dibayar: {total_harga}")
        print()
        print("Terima kasih sudah Belanja")
        break
    elif pilih == 4:
        print("\n".join(list2_romance))
        while True:
            comedy = input("Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: ")
            if comedy == 'selesai':
                break
            elif comedy in ['1', '2', '3']:
                if comedy == '1':
                    novel = Novel("1. Ubur-Ubur Lembur", 50000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif comedy == '2':
                    novel = Novel("2. Skripsick", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
                elif comedy == '3':
                    novel = Novel("3. KambingJantan", 75000)
                    total_harga += novel.harga
                    daftar_belanja.append(novel)
                    print(f"Anda membeli {novel.judul}")
            else:
                print("Pilihan tidak valid")

        while True:
            beli_lagi = input("Apakah anda ingin membeli novel lagi? (ya/tidak) ")
            if beli_lagi == "ya":
                menu()
                break
            elif beli_lagi == "tidak":
                break
            print("Daftar Belanja:")
        for novel in daftar_belanja:
            print(novel)

        print(f"Total Harga Yang harus dibayar : {total_harga}")
        print()
        print("Terima kasih sudah Belanja")
        break
# Out:
# Selamat datang di toko novel
#
# 1. Lihat Daftar Novel dengan genre mistery
# 2. Lihat Daftar Novel dengan genre romance
# 3. Lihat Daftar Novel dengan genre horror
# 4. Lihat Daftar Novel dengan genre comedy
# Pilih nomor menu: 1
# ----Novel Genre Misteri----
# 1. The Guardians
# 2. The Devil All the Time
# 3. Ivana Van Dijk
# Pilih novel yang ingin dibeli atau ketik 'selesai' untuk selesai: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ba1363df2b24> in <cell line: 53>()
#      68                     print(f"Anda membeli {novel.judul}")
#      69                 elif misteri == '2':
# ---> 70                     novel = Novel("2. The Devil All the Time", 75000)
#      71                     total_harga += novel.harga
#      72                     daftar_belanja.append(novel)
#
# TypeError: Novel() takes no arguments
